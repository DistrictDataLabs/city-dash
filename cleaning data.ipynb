# %% [markdown]
# # SELECTED SOCIAL CHARACTERISTICS IN THE UNITED STATES
# ## ACS_16_5YR_DP02_with_ann.csv

# %%
#import modules
import pandas as pd
import numpy as np
import sqlite3 as sql
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#Sql database to store data once it's ready
#con = sql.connect("acs02.db")

# %%
#open csv with pandas
df02 = pd.read_csv("./data/ACS_16_5YR_DP02_with_ann.csv", low_memory=False)

# %%
# Print the info of data frame
print(df02.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32990 entries, 0 to 32989
# Columns: 611 entries, GEO.id to HC04_VC218
# dtypes: object(611)
# memory usage: 153.8+ MB
# None

# %%
## Print the shape of df
print(df02.shape)
# Out:
# (32990, 611)

# %%
# Print the columns of df
print(df02.columns)
# Out:
# Index(['GEO.id', 'GEO.id2', 'GEO.display-label', 'HC01_VC03', 'HC02_VC03',
#        'HC03_VC03', 'HC04_VC03', 'HC01_VC04', 'HC02_VC04', 'HC03_VC04',
#        ...
#        'HC03_VC216', 'HC04_VC216', 'HC01_VC217', 'HC02_VC217', 'HC03_VC217',
#        'HC04_VC217', 'HC01_VC218', 'HC02_VC218', 'HC03_VC218', 'HC04_VC218'],
#       dtype='object', length=611)

# %%
# Print the head of df
df02.head()
# Out:
#            GEO.id GEO.id2 GEO.display-label  \
# 0              Id     Id2         Geography
# 1  8600000US01001   01001       ZCTA5 01001
# 2  8600000US01002   01002       ZCTA5 01002
# 3  8600000US01003   01003       ZCTA5 01003
# 4  8600000US01005   01005       ZCTA5 01005
#
#                                          HC01_VC03  \
# 0  Estimate; HOUSEHOLDS BY TYPE - Total households
# 1                                             7190
# 2                                             9561
# 3                                               26
# 4                                             1840
#
#                                            HC02_VC03  \
# 0  Margin of Error; HOUSEHOLDS BY TYPE - Total ho...
# 1                                                255
# 2                                                447
# 3                                                 21
# 4                                                187
#
#                                         HC03_VC03  \
# 0  Percent; HOUSEHOLDS BY TYPE - Total households
# 1                                            7190
# 2                                            9561
# 3                                              26
# 4                                            1840
#
#                                            HC04_VC03  \
# 0  Percent Margin of Error; HOUSEHOLDS BY TYPE - ...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                            HC01_VC04  \
# 0  Estimate; HOUSEHOLDS BY TYPE - Total household...
# 1                                               3943
# 2                                               4626
# 3                                                  0
# 4                                               1150
#
#                                            HC02_VC04  \
# 0  Margin of Error; HOUSEHOLDS BY TYPE - Total ho...
# 1                                                290
# 2                                                267
# 3                                                 19
# 4                                                144
#
#                                            HC03_VC04  \
# 0  Percent; HOUSEHOLDS BY TYPE - Total households...
# 1                                               54.8
# 2                                               48.4
# 3                                                0.0
# 4                                               62.5
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                           HC03_VC216  \
# 0  Percent; COMPUTERS AND INTERNET USE - Total ho...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           HC04_VC216  \
# 0  Percent Margin of Error; COMPUTERS AND INTERNE...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           HC01_VC217  \
# 0  Estimate; COMPUTERS AND INTERNET USE - Total h...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           HC02_VC217  \
# 0  Margin of Error; COMPUTERS AND INTERNET USE - ...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           HC03_VC217  \
# 0  Percent; COMPUTERS AND INTERNET USE - Total ho...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           HC04_VC217  \
# 0  Percent Margin of Error; COMPUTERS AND INTERNE...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           HC01_VC218  \
# 0  Estimate; COMPUTERS AND INTERNET USE - Total h...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           HC02_VC218  \
# 0  Margin of Error; COMPUTERS AND INTERNET USE - ...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           HC03_VC218  \
# 0  Percent; COMPUTERS AND INTERNET USE - Total ho...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           HC04_VC218
# 0  Percent Margin of Error; COMPUTERS AND INTERNE...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
# [5 rows x 611 columns]

# %%
# Print the tail of df
df02.tail()
# Out:
#                GEO.id GEO.id2 GEO.display-label HC01_VC03 HC02_VC03 HC03_VC03  \
# 32985  8600000US99923   99923       ZCTA5 99923         0         9         0
# 32986  8600000US99925   99925       ZCTA5 99925       337        33       337
# 32987  8600000US99926   99926       ZCTA5 99926       449        38       449
# 32988  8600000US99927   99927       ZCTA5 99927        58        31        58
# 32989  8600000US99929   99929       ZCTA5 99929      1037        63      1037
#
#       HC04_VC03 HC01_VC04 HC02_VC04 HC03_VC04    ...     HC03_VC216  \
# 32985       (X)         0         9         -    ...            (X)
# 32986       (X)       189        32      56.1    ...            (X)
# 32987       (X)       352        39      78.4    ...            (X)
# 32988       (X)         0         9       0.0    ...            (X)
# 32989       (X)       652        52      62.9    ...            (X)
#
#       HC04_VC216 HC01_VC217 HC02_VC217 HC03_VC217 HC04_VC217 HC01_VC218  \
# 32985        (X)        (X)        (X)        (X)        (X)        (X)
# 32986        (X)        (X)        (X)        (X)        (X)        (X)
# 32987        (X)        (X)        (X)        (X)        (X)        (X)
# 32988        (X)        (X)        (X)        (X)        (X)        (X)
# 32989        (X)        (X)        (X)        (X)        (X)        (X)
#
#       HC02_VC218 HC03_VC218 HC04_VC218
# 32985        (X)        (X)        (X)
# 32986        (X)        (X)        (X)
# 32987        (X)        (X)        (X)
# 32988        (X)        (X)        (X)
# 32989        (X)        (X)        (X)
#
# [5 rows x 611 columns]

# %%
# use pandas to get the summary statistics
df02.describe()
# Out:
#                 GEO.id GEO.id2 GEO.display-label HC01_VC03 HC02_VC03  \
# count            32990   32990             32990     32990     32990
# unique           32990   32990             32990     10446       692
# top     8600000US52576   11724       ZCTA5 67836         0        12
# freq                 1       1                 1       577       285
#
#        HC03_VC03 HC04_VC03 HC01_VC04 HC02_VC04 HC03_VC04    ...      \
# count      32990     32990     32990     32990     32990    ...
# unique     10446         2      8527       691       849    ...
# top            0       (X)         0        12         -    ...
# freq         577     32989       746       368       577    ...
#
#        HC03_VC216 HC04_VC216 HC01_VC217 HC02_VC217 HC03_VC217 HC04_VC217  \
# count       32990      32990      32990      32990      32990      32990
# unique          2          2          2          2          2          2
# top           (X)        (X)        (X)        (X)        (X)        (X)
# freq        32989      32989      32989      32989      32989      32989
#
#        HC01_VC218 HC02_VC218 HC03_VC218 HC04_VC218
# count       32990      32990      32990      32990
# unique          2          2          2          2
# top           (X)        (X)        (X)        (X)
# freq        32989      32989      32989      32989
#
# [4 rows x 611 columns]

# %%
# Print types of data
print(df02.dtypes)
# Out:
# GEO.id               object
# GEO.id2              object
# GEO.display-label    object
# HC01_VC03            object
# HC02_VC03            object
# HC03_VC03            object
# HC04_VC03            object
# HC01_VC04            object
# HC02_VC04            object
# HC03_VC04            object
# HC04_VC04            object
# HC01_VC05            object
# HC02_VC05            object
# HC03_VC05            object
# HC04_VC05            object
# HC01_VC06            object
# HC02_VC06            object
# HC03_VC06            object
# HC04_VC06            object
# HC01_VC07            object
# HC02_VC07            object
# HC03_VC07            object
# HC04_VC07            object
# HC01_VC08            object
# HC02_VC08            object
# HC03_VC08            object
# HC04_VC08            object
# HC01_VC09            object
# HC02_VC09            object
# HC03_VC09            object
#                       ...
# HC03_VC208           object
# HC04_VC208           object
# HC01_VC209           object
# HC02_VC209           object
# HC03_VC209           object
# HC04_VC209           object
# HC01_VC210           object
# HC02_VC210           object
# HC03_VC210           object
# HC04_VC210           object
# HC01_VC211           object
# HC02_VC211           object
# HC03_VC211           object
# HC04_VC211           object
# HC01_VC212           object
# HC02_VC212           object
# HC03_VC212           object
# HC04_VC212           object
# HC01_VC216           object
# HC02_VC216           object
# HC03_VC216           object
# HC04_VC216           object
# HC01_VC217           object
# HC02_VC217           object
# HC03_VC217           object
# HC04_VC217           object
# HC01_VC218           object
# HC02_VC218           object
# HC03_VC218           object
# HC04_VC218           object
# Length: 611, dtype: object

# %%
# delete first row
#df02 = df02.drop(df02.index[[0]])

# %% [markdown]
# Need to convert df to numeric

# %%
# convert df to numeric, coercing
#pd.to_numeric(df02, errors='ignore')

# %%
#convert zipcode column of ACS_16_5YR_DP02_with_ann.csv to int so we can merge it with zipcode file
df02['GEO.id2'] = df02['GEO.id2'].astype('int')

# %%
#open metadata file csv with pandas
df02meta = pd.read_csv("./data/ACS_16_5YR_DP02_metadata.csv", low_memory=False)
df02meta.head()

# %%
ls data/

# %%
#open zipcode csv with pandas
zipcode = pd.read_csv("./data/zipcode_states.csv")

# %%
# Print the head, type and info of zipcode df
print(zipcode.dtypes)
print(zipcode.info())
zipcode.head()

# %%
#merge df02 with zipcodes
df002 = pd.merge(left=df02, right=zipcode, left_on='GEO.id2', right_on='zipcode')

# %%
df002.head()
